# %% [markdown]
# # Introduction
# Matplotlib is the "grandfather" library of data visualization with Python. It was created by John Hunter. He created it to try to replicate MatLab's (another programming language) plotting capabilities in Python. So if you happen to be familiar with matlab, matplotlib will feel natural to you.
#
# It is an excellent 2D and 3D graphics library for generating scientific figures.
#
# Some of the major Pros of Matplotlib are:
#
# * Generally easy to get started for simple plots
# * Support for custom labels and texts
# * Great control of every element in a figure
# * High-quality output in many formats
# * Very customizable in general
#
# Matplotlib allows you to create reproducible figures programmatically. Let's learn how to use it! Before continuing this lecture, I encourage you just to explore the official Matplotlib web page: http://matplotlib.org/

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# <p style="color: green; font-size: 18px">The above line will allow us to see the plots, inside the Jupiter Notebook</p>

# %%
import numpy as np

# %%
x = np.linspace(0,5,11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %% [markdown]
# # Matplotlib Functional method

# %%
plt.plot(x,y)

# %% [markdown]
# ### Adding x-label, y-label and title

# %%
plt.plot(x, y)
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %% [markdown]
# ## Creating MultiPlots

# %% [markdown]
# ### subplot function
# * The `subplot()` function takes three arguments that describes the layout of the figure.
# * The layout is organized in rows and columns, which are represented by the `first` and `second` argument.
# * The `third` argument represents the index of the current plot.

# %%
# plt.subplot(nrows, ncols, plot_number)
plt.subplot(1,2,1)
plt.plot(x,y,'r-')
plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %% [markdown]
# <p style="color: green; font-size: 18px;">1<= <code>plot_number</code><=2</p>

# %% [markdown]
# # Matplotlib Object Orient Method
# The main idea in using the more formal Object Oriented method is to create figure objects and then just call methods or attributes off of that object. This approach is nicer when dealing with a canvas that has multiple plots on it.
#
# To begin we create a figure instance. Then we can add axes to that figure:

# %%
fig = plt.figure() # this line will create a canvas.

axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # [left, bottom, width, height] range(0,1)

axes.plot(x,y)
axes.set_xlabel('X label')
axes.set_ylabel('Y label')
axes.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %% [markdown]
# ### Displaying two sets of figure on a single canvas.

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # setting up the main axes.
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3])

axes1.plot(x,y)
axes2.plot(y,x)
axes1.set_title("larger Plot")
axes2.set_title("smaller Plot")
# Out:
# Text(0.5, 1.0, 'smaller Plot')

# %% [markdown]
# ## Creating Sub-plots
# The `plt.subplots()` object will act as a more automatic axis manager. i.e. it will automatically call `fig.add_axes()` method based on the parameters.

# %%
# Use similar to plt.figure() except use tuple unpacking to grab fig and axes
fig, axes = plt.subplots(nrows=3, ncols=2)

# %% [markdown]
# ### fixing the overlapping of vlaues.

# %%
fig, axes = plt.subplots(nrows=3, ncols=2)
plt.tight_layout()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

# Iterating through the axes object.
for current_ax in axes:
    current_ax.plot(x,y)

# %% [markdown]
# #### axis object is the list of matplotlib axes.

# %%
axes
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %% [markdown]
#  <p style="color: green; font-size: 18px;">Means we can iterate through it.</p>

# %% [markdown]
# ### We can also access the matplotlib.axes objects from axes object.

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

axes[0].plot(x,y)
axes[1].plot(y,x)

# %% [markdown]
# # Figure Size, Aspect ratio and DPI
# Matplotlib allows the aspect ratio, DPI and figure size to be specified when the Figure object is created. You can use the `figsize` and `dpi` keyword arguments.
# * `figsize` is a tuple of the width and height of the figure in `inches`
# * `dpi` is the dots-per-inch (pixel per inch).

# %%
fig = plt.figure(figsize=(3,4), dpi=100)

ax = fig.add_axes([0,0,1,1]) # left, bottom, width, height.
ax.plot(x,y)

# %%
fig = plt.figure(figsize=(8,2), dpi=100)

ax = fig.add_axes([0,0,1,1]) # left, bottom, width, height.
ax.plot(x,y)

# %% [markdown]
# ## Doing the same with subplots

# %%
fig, axes = plt.subplots(nrows=2, ncols=1,figsize=(8,2)) # default value of nrows and ncols = 1;

axes[0].plot(x,y)
axes[1].plot(y,x)

plt.tight_layout()

# %% [markdown]
# ## Saving figures
# Matplotlib can generate high-quality output in a number formats, including PNG, JPG, EPS, SVG, PGF and PDF.

# %% [markdown]
# To save a figure to a file we can use the `savefig` method in the `Figure` class:

# %%
fig.savefig('my_picture.png')

# %% [markdown]
# ## Legends
# You can use the **label="label text"** keyword argument when plots or other objects are added to the figure, and then using the **legend** method without arguments to add the legend to the figure:

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2, label='x**2')
ax.plot(x,x**3, label='x**3')

ax.legend() # loc=0 by default.

# %% [markdown]
# We can also move our `legends` position, by passing an argument `loc` which takes an integer value.
# * 1. `best`: 0
#   2. `upper right`: 1
#   3. `upper left`: 2
#   4. `lower left`: 3
#   5. `lower right`: 4
#   6. `right`: 5
#   7. `center left`: 6
#   8. `center right`: 7
#   9. `lower center`: 8
#   10. `upper center`: 9
#   11. `center`: 10

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2, label='x**2')
ax.plot(x,x**3, label='x**3')

ax.legend(loc=10) # loc=0 by default.

# %% [markdown]
# We can also pass a `tuple` containing `x` and `y` location.

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2, label='x**2')
ax.plot(x,x**3, label='x**3')

ax.legend(loc=(0.2, 0.2)) # loc=0 by default.

# %% [markdown]
# # Setting colors, linewidth and linetypes.
# Matplotlib gives you *a lot* of options for customizing colors, linewidths, and linetypes.

# %% [markdown]
# ### Colors with MatLab like syntax
